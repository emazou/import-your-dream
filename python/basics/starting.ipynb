# %% [markdown]
# <script src="https://gist.github.com/emazou/fdb2831724f6fe7204e6cb3a9911046e.js"></script>

# %% [markdown]
# <script src="https://gist.github.com/emazou/fdb2831724f6fe7204e6cb3a9911046e.js"></script>
